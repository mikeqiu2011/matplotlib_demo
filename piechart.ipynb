# %%
from matplotlib import pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
slices = [60, 40]
plt.pie(slices)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f90661b06d0>,
# ...
#  [Text(-0.3399187721714582, 1.046162142464278, ''),
#   Text(0.3399188701202255, -1.0461621106387813, '')])

# %%
slices = [120, 80]
labels = ['meat', 'vegetable']
plt.pie(slices, labels=labels, wedgeprops={'edgecolor': 'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9065f5b340>,
# ...
#  [Text(-0.3399187721714582, 1.046162142464278, 'meat'),
#   Text(0.3399188701202255, -1.0461621106387813, 'vegetable')])

# %%
slices = [120, 80]
labels = ['meat', 'vegetable']
colors = ['#008fd5', '#fc4f30']
plt.pie(slices, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x7f90668eadc0>,
# ...
#  [Text(-0.3399187721714582, 1.046162142464278, 'meat'),
#   Text(0.3399188701202255, -1.0461621106387813, 'vegetable')])

# %% [markdown]
# > visual representation is not good for over 5 items

# %%
labels = ['TypeScript', 'C++', 'PHP', 'C#', 'Bash/Shell/PowerShell', 'Java', 'Python', 'SQL', 'HTML/CSS', 'JavaScript']
slices = [18523, 20524, 23030, 27097, 31991, 35917, 36443, 47544, 55466, 59219]
plt.pie(slices, labels=labels);

# %%
labels = ['Java', 'Python', 'SQL', 'HTML/CSS', 'JavaScript']
slices = [35917, 36443, 47544, 55466, 59219]
plt.pie(slices, labels=labels);

# %%
# emphasis
labels = ['Java', 'Python', 'SQL', 'HTML/CSS', 'JavaScript']
slices = [35917, 36443, 47544, 55466, 59219]
explode = [0, .1, 0, 0, 0]
plt.pie(slices, labels=labels, explode=explode);

# %%
# additional parameter
plt.pie(slices, labels=labels, explode=explode,
       startangle=90, autopct='%1.1f%%');
