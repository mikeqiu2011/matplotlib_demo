# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xvals = np.arange(0, 10, 0.1)
plt.plot(xvals, np.sin(xvals))

# %%
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['figure.dpi'] = 150

# %% [markdown]
# # labels

# %%
plt.plot(xvals, np.sin(xvals))
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# # multiple plot

# %%
plt.plot(xvals, np.sin(xvals))
plt.plot(xvals, np.cos(xvals))

# %% [markdown]
# # legend and title

# %%
plt.plot(xvals, np.sin(xvals), label=r'sin(x)')
plt.plot(xvals, np.cos(xvals), label=r'cos(x)')
plt.legend()

# %% [markdown]
# # line color

# %%
plt.plot(xvals, np.sin(xvals), label=r'sin(x)', color='red')

# %% [markdown]
# # line style

# %%
plt.plot(xvals, np.sin(xvals), marker='o', linestyle='none')
plt.plot(xvals, np.cos(xvals), linestyle='--')

# %% [markdown]
# # Axis limit

# %%
plt.plot(xvals, np.sin(xvals), color='orange', linestyle='--')
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
plt.plot(xvals, np.sin(xvals), color='orange', linestyle='--')
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# # histgram

# %%
rands = np.random.normal(size=1000)

# %%
plt.hist(rands)
# Out:
# (array([  4.,  12.,  54., 118., 262., 267., 184.,  73.,  22.,   4.]),
#  array([-3.53226812, -2.83752874, -2.14278936, -1.44804998, -0.7533106 ,
#         -0.05857122,  0.63616816,  1.33090754,  2.02564692,  2.7203863 ,
#          3.41512568]),
#  <BarContainer object of 10 artists>)
